# %% [markdown]
# <a href="https://colab.research.google.com/github/kdzioba/machine-learning-bootcamp/blob/main/regresja_liniowa/02_gradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import plotly.express as px

np.random.seed(42)

# %% [markdown]
# Przygotowanie danych

# %%
X1 = np.array([1, 2, 3, 4, 5, 6])
Y = np.array([3000, 3250, 3500, 3750, 4000, 4250])
m = len(X1)

print(f'Lata pracy: {X1}')
print(f'Wynagrodzenie: {Y}')
print(f'Liczba próbek: {m}')
# Out:
# Lata pracy: [1 2 3 4 5 6]
# Wynagrodzenie: [3000 3250 3500 3750 4000 4250]
# Liczba próbek: 6

# %%
X1 = X1.reshape(m, 1)
print(X1)
print(X1.shape)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [6]]
# (6, 1)

# %%
bias = np.ones((m, 1))
print(bias)
print(bias.shape)
# Out:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]
# (6, 1)

# %%
X = np.append(bias, X1, axis=1)
print(X)
print(X.shape)
# Out:
# [[1. 1.]
#  [1. 2.]
#  [1. 3.]
#  [1. 4.]
#  [1. 5.]
#  [1. 6.]]
# (6, 2)

# %%
Y = Y.reshape(-1, 1)
print(Y)
print(Y.shape)
# Out:
# [[3000]
#  [3250]
#  [3500]
#  [3750]
#  [4000]
#  [4250]]
# (6, 1)

# %% [markdown]
# Równanie normalne

# %%
L = np.linalg.inv(np.dot(X.T, X))
L
# Out:
# array([[ 0.86666667, -0.2       ],
#        [-0.2       ,  0.05714286]])

# %%
P = np.dot(X.T, Y)
P
# Out:
# array([21750., 80500.])

# %%
np.dot(L, P)
# Out:
# array([2750.,  250.])

# %% [markdown]
# Regresja liniowa przy pomocy scikit-learn

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()
regression.fit(X1, Y)

print(regression.intercept_)
print(regression.coef_[0])
# Out:
# 2750.0
# 250.0

# %% [markdown]
# Metoda gradientu prostego

# %% [markdown]
# ### 1. Losowa inicjalizacja parametrów

# %%
eta = 0.01

weights = np.random.randn(2, 1)
print(X)
print(weights)
# Out:
# [[1. 1.]
#  [1. 2.]
#  [1. 3.]
#  [1. 4.]
#  [1. 5.]
#  [1. 6.]]
# [[1.57921282]
#  [0.76743473]]

# %%
intercept = []
coef = []

for i in range(5000):
    gradient = (2 / m) * X.T.dot(X.dot(weights) - Y)
    weights = weights - eta * gradient
    intercept.append(weights[0][0])
    coef.append(weights[1][0])

print(weights)
# Out:
# [[2749.99997065]
#  [ 250.00000685]]

# %%
df = pd.DataFrame(data={'intercept': intercept, 'coef': coef})
df.head()
# Out:
#     intercept        coef
# 0   73.993908  268.757435
# 1  126.201010  450.388106
# 2  164.649822  573.269643
# 3  193.727950  656.185697
# 4  216.420393  711.915079

# %%
px.line(df, y='intercept', width=800, title='Dopasowanie: intercept')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d9709b9f-08f8-41ec-8430-36280f53d68e" class="plotly-graph-div" style="height:525px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d9709b9f-08f8-41ec-8430-36280f53d68e")) {
#                     Plotly.newPlot(
#                         'd9709b9f-08f8-41ec-8430-36280f53d68e',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "intercept=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "xaxis": "x", "y": [73.99390812815653, 126.20100954143103, 164.64982193826393, 193.7279504823225, 216.42039267154084, 234.7579292773492, 250.12217192249608, 263.4530918615552, 275.39020515307567, 286.36862320649936, 296.6843975166375, 306.53897473942334, 316.0694401964057, 325.36909301843446, 334.50144374777807, 343.5097371327791, 352.42343063892406, 361.26260188476056, 370.04094709203116, 378.7678209800854, 387.44962453939473, 396.09074915671727, 404.6942189191429, 413.26212758436805, 421.7959358590981, 430.296673642817, 438.7650776179645, 447.201